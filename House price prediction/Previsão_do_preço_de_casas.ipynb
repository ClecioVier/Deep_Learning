# %% [markdown]
# # Projeto 4: Previsão do preço de casas

# %% [markdown]
# Base de dados: https://www.kaggle.com/harlfoxem/housesalesprediction

# %% [markdown]
# # Etapa 1: Importação das bibliotecas

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
tf.__version__
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# '2.12.0'

# %% [markdown]
# # Etapa 2: Importação da base de dados

# %%
house_df = pd.read_csv('kc-house-data.csv', encoding = 'ISO-8859-1')

# %%
house_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
house_df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21603        2270              0      2003             0    98065  47.5389
# 21604        1490              0      2014             0    98144  47.5699
# 21605        2520              0      2014             0    98056  47.5137
# 21606        2600            910      2009             0    98136  47.5537
# 21607        1180            130      2008             0    98116  47.5773
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21603 -121.881           2270        5731
# 21604 -122.288           1400        1230
# 21605 -122.167           2520        6023
# 21606 -122.398           2050        6200
# 21607 -122.409           1330        1265
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [10 rows x 21 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # Etapa 3: Visualização dos dados

# %%
sns.scatterplot(x = 'sqft_living', y = 'price', data = house_df);

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house_df.corr(), annot = True)
# Out:
# <ipython-input-40-cca5abf2f039>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(house_df.corr(), annot = True)
# <Axes: >

# %%
house_df.hist(bins = 20, figsize = (20, 20), color = 'b');

# %%
sns.pairplot(house_df);

# %% [markdown]
# # Etapa 4: Tratamento da base de dados

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
X = house_df[selected_features]

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0         3       1.00         1180      5650     1.0        1180
# 1         3       2.25         2570      7242     2.0        2170
# 2         2       1.00          770     10000     1.0         770
# 3         4       3.00         1960      5000     1.0        1050
# 4         3       2.00         1680      8080     1.0        1680
#
#    sqft_basement
# 0              0
# 1            400
# 2              0
# 3            910
# 4              0

# %%
y = house_df['price']

# %%
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
X.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.09758772,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.4       , 0.20614035,
#         0.08298755],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.05263158,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.4       , 0.14364035,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ]])

# %%
X_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1, 1)

# %%
y.shape
# Out:
# (21613, 1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
X_train.shape
# Out:
# (16209, 7)

# %%
X_test.shape
# Out:
# (5404, 7)

# %% [markdown]
# # Etapa 5: Construção e criação do modelo

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units = 100, activation = 'relu', input_shape = (7, )))
model.add(tf.keras.layers.Dense(units = 100, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 100, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 1, activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 21,101
# Trainable params: 21,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "Adam", loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 3s 5ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 2/100
# 260/260 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 3/100
# 260/260 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 9.3319e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.6017e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 8.9993e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 8.9641e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.2812e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.0800e-04
# Epoch 9/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.4565e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8668e-04 - val_loss: 8.9117e-04
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9837e-04 - val_loss: 8.9672e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9812e-04 - val_loss: 8.8459e-04
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9318e-04 - val_loss: 8.7357e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9481e-04 - val_loss: 8.8377e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7910e-04 - val_loss: 9.0608e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 8.9395e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.7637e-04 - val_loss: 8.7443e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.8921e-04 - val_loss: 8.8065e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.6971e-04 - val_loss: 9.1408e-04
# Epoch 20/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7190e-04 - val_loss: 8.7612e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7495e-04 - val_loss: 8.6619e-04
# Epoch 22/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6492e-04 - val_loss: 9.6096e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7781e-04 - val_loss: 8.7066e-04
# Epoch 24/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6480e-04 - val_loss: 8.7590e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6665e-04 - val_loss: 8.6228e-04
# Epoch 26/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6299e-04 - val_loss: 9.7047e-04
# Epoch 27/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7168e-04 - val_loss: 8.9069e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.5895e-04 - val_loss: 8.8698e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.7457e-04 - val_loss: 8.7732e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.5437e-04 - val_loss: 8.7555e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5871e-04 - val_loss: 8.8285e-04
# Epoch 32/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.5359e-04 - val_loss: 8.7771e-04
# Epoch 33/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.7294e-04 - val_loss: 8.6722e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5209e-04 - val_loss: 9.7157e-04
# Epoch 35/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4978e-04 - val_loss: 8.7031e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4690e-04 - val_loss: 8.6725e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4480e-04 - val_loss: 8.6819e-04
# Epoch 38/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5384e-04 - val_loss: 8.7803e-04
# Epoch 39/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5552e-04 - val_loss: 8.9198e-04
# Epoch 40/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5400e-04 - val_loss: 8.7762e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5337e-04 - val_loss: 8.7531e-04
# Epoch 42/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4571e-04 - val_loss: 9.1185e-04
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4661e-04 - val_loss: 9.0270e-04
# Epoch 44/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5020e-04 - val_loss: 9.5857e-04
# Epoch 45/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3887e-04 - val_loss: 8.7499e-04
# Epoch 46/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3557e-04 - val_loss: 8.9834e-04
# Epoch 47/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4854e-04 - val_loss: 8.6840e-04
# Epoch 48/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.3631e-04 - val_loss: 8.7198e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.4286e-04 - val_loss: 8.7447e-04
# Epoch 50/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4230e-04 - val_loss: 8.9902e-04
# Epoch 51/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5315e-04 - val_loss: 9.0560e-04
# Epoch 52/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3835e-04 - val_loss: 8.8021e-04
# Epoch 53/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4230e-04 - val_loss: 8.8766e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3206e-04 - val_loss: 9.2260e-04
# Epoch 55/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3616e-04 - val_loss: 8.6232e-04
# Epoch 56/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2768e-04 - val_loss: 9.2149e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3269e-04 - val_loss: 8.8215e-04
# Epoch 58/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2443e-04 - val_loss: 8.5739e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2179e-04 - val_loss: 8.7266e-04
# Epoch 60/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3906e-04 - val_loss: 8.6116e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1104e-04 - val_loss: 8.7323e-04
# Epoch 62/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2290e-04 - val_loss: 8.7666e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1420e-04 - val_loss: 8.5846e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0990e-04 - val_loss: 9.0447e-04
# Epoch 65/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2383e-04 - val_loss: 8.9155e-04
# Epoch 66/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1962e-04 - val_loss: 9.1309e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1416e-04 - val_loss: 8.7262e-04
# Epoch 68/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0669e-04 - val_loss: 8.6482e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9764e-04 - val_loss: 8.8570e-04
# Epoch 70/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0522e-04 - val_loss: 9.3280e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0770e-04 - val_loss: 8.7810e-04
# Epoch 72/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9718e-04 - val_loss: 8.7062e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0801e-04 - val_loss: 8.7362e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0724e-04 - val_loss: 9.4858e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1185e-04 - val_loss: 9.2254e-04
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9716e-04 - val_loss: 8.6262e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8864e-04 - val_loss: 9.6777e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0988e-04 - val_loss: 9.0225e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9413e-04 - val_loss: 8.4482e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9103e-04 - val_loss: 8.8015e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9832e-04 - val_loss: 8.5335e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9075e-04 - val_loss: 8.9630e-04
# Epoch 83/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0218e-04 - val_loss: 9.9295e-04
# Epoch 84/100
# 260/260 [==============================] - 2s 8ms/step - loss: 8.8412e-04 - val_loss: 9.4905e-04
# Epoch 85/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1688e-04 - val_loss: 9.4485e-04
# Epoch 86/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0212e-04 - val_loss: 8.9876e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8590e-04 - val_loss: 8.6870e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8390e-04 - val_loss: 8.6836e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8523e-04 - val_loss: 8.5329e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9939e-04 - val_loss: 8.6397e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9755e-04 - val_loss: 8.7243e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9313e-04 - val_loss: 8.7295e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8700e-04 - val_loss: 8.6854e-04
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8044e-04 - val_loss: 8.4308e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6530e-04 - val_loss: 8.7764e-04
# Epoch 96/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7518e-04 - val_loss: 8.6440e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7013e-04 - val_loss: 8.9847e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7819e-04 - val_loss: 8.7991e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6636e-04 - val_loss: 8.8099e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7422e-04 - val_loss: 8.7950e-04

# %% [markdown]
# # Etapa 6: Avaliação do modelo

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend('Training and Validation Loss');

# %%
# 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot','floors', 'sqft_above', 'sqft_basement'
X_test_1 = np.array([[ 4, 3, 1960, 5000, 1, 2000, 3000 ]])

scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_test_1)

y_predict_1 = model.predict(X_test_scaled_1)

y_predict_1 = scaler.inverse_transform(y_predict_1)
y_predict_1
# Out:
# 1/1 [==============================] - 0s 239ms/step
# array([[188804.56]], dtype=float32)

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values');
# Out:
# 169/169 [==============================] - 1s 6ms/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'b')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000);

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 5404

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 247125.982
# MSE = 61071250802.13462
# MAE = 155984.6290305792
# R2 = 0.5843491801310856
# Adjusted R2 = 0.5838099741008629

# %% [markdown]
# # Etapa 7: Aumento da quantidade de características

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built', 
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house_df[selected_features]

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0         3       1.00         1180      5650     1.0        1180
# 1         3       2.25         2570      7242     2.0        2170
# 2         2       1.00          770     10000     1.0         770
# 3         4       3.00         1960      5000     1.0        1050
# 4         3       2.00         1680      8080     1.0        1680
#
#    sqft_basement  waterfront  view  condition  grade  sqft_above  yr_built  \
# 0              0           0     0          3      7        1180      1955
# 1            400           0     0          3      7        2170      1951
# 2              0           0     0          3      6         770      1933
# 3            910           0     0          5      7        1050      1965
# 4              0           0     0          3      8        1680      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.21760797, 0.16193426,
#         0.00574235],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.16611296, 0.22216486,
#         0.00802712],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.23754153, 0.3994149 ,
#         0.00851302],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.18272425, 0.10686629,
#         0.00155764],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.37375415, 0.17398038,
#         0.00073057],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.18272425, 0.10686629,
#         0.00081098]])

# %%
y = house_df['price']

# %%
y = y.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(19, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 3s 5ms/step - loss: 8.3310e-04 - val_loss: 6.7095e-04
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 5.3957e-04 - val_loss: 4.9580e-04
# Epoch 3/100
# 260/260 [==============================] - 1s 3ms/step - loss: 5.0316e-04 - val_loss: 4.5084e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.5268e-04 - val_loss: 4.1683e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.3317e-04 - val_loss: 3.4061e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.8521e-04 - val_loss: 3.0021e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.7701e-04 - val_loss: 3.6190e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.5663e-04 - val_loss: 3.3627e-04
# Epoch 9/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.3589e-04 - val_loss: 2.9477e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.4485e-04 - val_loss: 2.9708e-04
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0545e-04 - val_loss: 2.8431e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1950e-04 - val_loss: 2.6698e-04
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1095e-04 - val_loss: 2.8933e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 4ms/step - loss: 3.0109e-04 - val_loss: 2.7626e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 5ms/step - loss: 3.0564e-04 - val_loss: 3.3556e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 4ms/step - loss: 2.9145e-04 - val_loss: 3.3580e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0117e-04 - val_loss: 2.5684e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.6999e-04 - val_loss: 3.0516e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2